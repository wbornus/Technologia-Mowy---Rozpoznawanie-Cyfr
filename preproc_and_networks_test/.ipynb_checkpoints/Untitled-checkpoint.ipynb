# %%
import os
import numpy as np
from scipy.io import wavfile
import random
from matplotlib import pyplot as plt

# %%
fnames = os.listdir('../train')
#print(fnames)
n_classes = 10

speaker_idxs = []
for i in range(4):
    speaker_idxs.append(random.randint(0, (len(fnames) // n_classes)-1))

print(speaker_idxs)
X_train, X_test = [], []
y_train, y_test = [], []
len_files = []
for  it in range(len(fnames)):
    fs, tmp = wavfile.read('../train/'+fnames[it])
    #checking if data length is cohesive
    tmp = tmp / max(abs(tmp))
    if len(tmp) < fs:
        len_to_append = fs - len(tmp)
        to_append = np.zeros(len_to_append)
        tmp = np.append(tmp, to_append)
    else:
        tmp = tmp[:fs]
    
    if it//n_classes in speaker_idxs:
        X_test.append(tmp)
        y_test.append(it % n_classes)
    else:
        X_train.append(tmp)
        y_train.append(it % n_classes)
    
# plt.plot(tmp)
# plt.show()
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
# Out:
# [21, 11, 0, 12]
# c:\users\wiktor\appdata\local\programs\python\python36\lib\site-packages\scipy\io\wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
"""MFCC and FNN"""

from python_speech_features import mfcc
from tqdm import tqdm
X_train_mfcc = []
for it in tqdm(range(X_train.shape[0])):
    tmp = X_train[it, :]
    tmp_mfcc = mfcc(tmp).tolist()
    X_train_mfcc.append(tmp_mfcc)
    
X_test_mfcc = []
for it in tqdm(range(X_test.shape[0])):
    tmp = X_test[it, :]
    tmp_mfcc = mfcc(tmp).tolist()
    X_test_mfcc.append(tmp_mfcc)
    
X_train_mfcc = np.array(X_train_mfcc)
X_test_mfcc = np.array(X_test_mfcc)

print(X_train_mfcc.shape)
plt.imshow(X_train_mfcc[100, :, :])

from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.constraints import unit_norm
from keras.optimizers import Adam

input_shape = X_train_mfcc.shape[1] * X_train_mfcc.shape[2]
print(input_shape)

X_train_mfcc_flat = np.reshape(X_train_mfcc, (-1, input_shape))
X_test_mfcc_flat = np.reshape(X_test_mfcc, (-1, input_shape))

"""onehoting network outputs"""
from keras.utils import to_categorical
y_train_onehot = to_categorical(y_train, 10)
y_test_onehot = to_categorical(y_test, 10)

model_dense_input = Input(shape=(input_shape,))
model_dense = Dense(units=128, activation='relu', input_dim=input_shape,
             kernel_constraint=unit_norm())(model_dense_input)
model_dense = Dropout(0.5)(model_dense)
model_dense = Dense(units=128, activation='relu')(model_dense)
model_dense = Dense(units=64, activation='relu')(model_dense)
model_dense = Dense(units=10, activation='softmax')(model_dense)
model_dense = Model(inputs=model_dense_input, output=model_dense)

model_dense.summary()

adam = Adam(lr = 0.001)
model_dense.compile(loss='categorical_crossentropy',
             optimizer = adam, metrics=['accuracy'])

model_dense.fit(X_train_mfcc_flat, y_train_onehot, epochs=100, steps_per_epoch=1, 
          validation_data=(X_test_mfcc_flat, y_test_onehot), validation_steps=100)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 190.50it/s]
# (180, 99, 13)
# 1287
# c:\users\wiktor\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:46: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_4 (InputLayer)         (None, 1287)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               164864
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               16512
# ...

# %%
def predict_mfcc_to_digit(data, fs, model):
    if len(data) < fs:
        len_to_append = fs - len(data)
        to_append = np.zeros(len_to_append)
        data = np.append(data, to_append)
    else:
        data = data[:fs]
        
    data_mfcc = mfcc(data, fs)
    input_shape = data_mfcc.shape[0] * data_mfcc.shape[1]
    data_mfcc = np.reshape(data_mfcc, (1, input_shape))
    
    prediction = model.predict(data_mfcc)
    digit = np.argmax(prediction)
    
    return digit

# %%
fs, data = wavfile.read('ex_data.wav')
print(predict_mfcc_to_digit(data, fs, model_dense))
# Out:
# 0

# %%
model_dense.save('model_mfcc_dense.h5')

# %%
"""Spectrograms and CNN"""
# Out:
# 'Spectrograms and CNN'

# %%
from scipy.signal import spectrogram
from tqdm import tqdm
import math
# X_train_spec = []
# for it in tqdm(range(X_train.shape[0])):
#     tmp = X_train[it, :]
#     tmp_spec = spectrogram(tmp, fs, window='hamming',
#                               nperseg=400, noverlap=200,
#                               nfft=512, ).tolist()
#     X_train_mfcc.append(tmp_mfcc)
    
f, t, X_train_spec = spectrogram(X_train, fs, window='hamming',
                              nperseg=400, noverlap=200,
                              nfft=512, axis=1)

X_train_spec = np.log(X_train_spec)
X_train_spec = np.nan_to_num(X_train_spec, neginf=0.0001)

# for it_i in range(X_train_spec.shape[]):
    

f, t, X_test_spec = spectrogram(X_test, fs, window='hamming',
                              nperseg=400, noverlap=200,
                              nfft=512, axis=1)
X_test_spec = np.log(X_test_spec)
X_test_spec = np.nan_to_num(X_test_spec, neginf=0.0001)
# X_test_spec = []
# for it in tqdm(range(X_test.shape[0])):
#     tmp = X_test[it, :]
#     tmp_mfcc = mfcc(tmp).tolist()
#     X_test_mfcc.append(tmp_mfcc)
    
# X_train_mfcc = np.array(X_train_mfcc)
# X_test_mfcc = np.array(X_test_mfcc)

print(X_train_spec.shape)
plt.pcolormesh(t, f, X_test_spec[25, :, :], vmin=None, vmax=None, snap=True)
plt.xlabel('time')
plt.ylabel('freq')
print(y_test[25])
# Out:
# c:\users\wiktor\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()
# c:\users\wiktor\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in log
# (180, 257, 79)
# 5

# %%
X_train_spec = np.reshape(X_train_spec, (-1, X_train_spec.shape[1], 
                                             X_test_spec.shape[2], 1))

X_test_spec = np.reshape(X_test_spec, (-1, X_test_spec.shape[1], 
                                             X_test_spec.shape[2], 1))

print(X_train_spec.shape, "\n", X_test_spec.shape)

input_shape_spec = X_test_spec.shape[1]*X_test_spec.shape[2]

X_train_spec_flat = np.reshape(X_train_spec, (-1, input_shape_spec))

X_test_spec_flat = np.reshape(X_test_spec, (-1, input_shape_spec))

print(X_train_spec_flat.shape, "\n", X_test_spec_flat.shape)

X_train_spec_flat = (X_train_spec_flat - 
                     np.mean(X_train_spec_flat)) / np.std(X_train_spec_flat)

X_test_spec_flat = (X_test_spec_flat - 
                     np.mean(X_train_spec_flat)) / np.std(X_train_spec_flat)
print(X_train_spec_flat.shape, "\n", X_test_spec_flat.shape)
# Out:
# (180, 257, 79, 1)
#  (40, 257, 79, 1)
# (180, 20303)
#  (40, 20303)
# (180, 20303)
#  (40, 20303)

# %%
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Conv2D, Dropout, Flatten
from keras.constraints import unit_norm
from keras.optimizers import Adam, SGD
from keras.constraints import unit_norm

model_conv_input = Input(shape=(X_train_spec.shape[1], 
                                X_train_spec.shape[2],
                                X_train_spec.shape[3]))
model_conv = Conv2D(filters=8, kernel_size=(5,5), strides=(8,8),
                    padding='same', activation='sigmoid')(model_conv_input)
# model_conv = Conv2D(filters=16, kernel_size=(5,5), strides=(4,4),
#                     padding='same', activation='sigmoid')(model_conv)
model_conv = Flatten()(model_conv)
model_conv = Dense(units=100, activation='sigmoid')(model_conv)
# model_conv = Dense(units=128, activation='sigmoid')(model_conv)
model_conv = Dense(units=10, activation='softmax')(model_conv)
model_conv = Model(inputs=model_conv_input, output=model_conv)

model_conv.summary()
# Out:
# c:\users\wiktor\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:19: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         (None, 257, 79, 1)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 33, 10, 8)         208
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2640)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               264100
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1010
# ...
# Total params: 265,318
# Trainable params: 265,318
# ...

# %%
adam = Adam(lr = 0.005)
model_conv.compile(loss='categorical_crossentropy', optimizer = adam, metrics=['accuracy'])

# %%
model_conv.fit(X_train_spec, y_train_onehot, epochs=200, steps_per_epoch=1,
              validation_data=(X_test_spec, y_test_onehot), validation_steps=1)
# Out:
# Train on 180 samples, validate on 40 samples
# Epoch 1/200
# 1/1 [==============================] - 1s 690ms/step - loss: 2.3855 - acc: 0.1000 - val_loss: 3.0366 - val_acc: 0.1000
# Epoch 2/200
# 1/1 [==============================] - 0s 100ms/step - loss: 3.0205 - acc: 0.1000 - val_loss: 2.8831 - val_acc: 0.2000
# Epoch 3/200
# 1/1 [==============================] - 0s 100ms/step - loss: 2.8679 - acc: 0.1778 - val_loss: 2.8202 - val_acc: 0.1250
# Epoch 4/200
# 1/1 [==============================] - 0s 90ms/step - loss: 2.8122 - acc: 0.1000 - val_loss: 2.6899 - val_acc: 0.1750
# Epoch 5/200
# 1/1 [==============================] - 0s 90ms/step - loss: 2.6723 - acc: 0.1444 - val_loss: 2.5881 - val_acc: 0.2000
# Epoch 6/200
# 1/1 [==============================] - 0s 90ms/step - loss: 2.5772 - acc: 0.1778 - val_loss: 2.5051 - val_acc: 0.1250
# Epoch 7/200
# 1/1 [==============================] - 0s 80ms/step - loss: 2.4861 - acc: 0.1556 - val_loss: 2.4346 - val_acc: 0.1000
# ...

# %%
def predict_spectrogram_to_digit(data, fs, model):
    if len(data) < fs:
        len_to_append = fs - len(data)
        to_append = np.zeros(len_to_append)
        data = np.append(data, to_append)
    else:
        data = data[:fs]
        
    _, _, data_spec = spectrogram(data, fs, window='hamming',
                              nperseg=400, noverlap=200,
                              nfft=512)
    data_spec = np.reshape(data_spec, (1, data_spec.shape[0],
                                      data_spec.shape[1], 1))
    
    prediction = model.predict(data_spec)
    digit = np.argmax(prediction)
    
    return digit

# %%
fs, data = wavfile.read('ex_data.wav')
print(predict_spectrogram_to_digit(data, fs, model_conv))
# Out:
# 2
